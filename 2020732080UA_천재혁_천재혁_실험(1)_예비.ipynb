# %%
print ('hello world!')
print ('hello World!!2')
# Out:
# hello world!
# hello World!!2

# %% [markdown]
# # H1
#
# ## h1
#
# **진하게**
#
# __밑줄__
#
# ~~취소~~
#
# _이탤릭_
#
# > 블럭 1단계
#
# >> 블럭 2단계
#
# * 사과
#
# *오렌지
#
# + 딸기 (tab)
#
# + 파인애플 (tab)
#
#
# 1. 참외
#
# 2. 수박
#
#
# [바로가기] (http://google.com)
#  <http://google.com>
#
#
# ***
# 수평선
#
# -------
#
#
# ![이미지설명문구](https://www.nongmin.com/-/raw/srv-nongmin/data2/content/image/2022/02/13/.cache/512/20220213191115.jpg)
#
#
# ------
#
# 문장내 $\frac{1+s}{s(s+2)}$ 삽입
# $$\frac{1+s}{s(s+2)}$$
#
#
# ------
#
# + 선택된 셀을 실행 : Ctrl + Enter
#
# + 실행 후 다음 셀 추가 : Alt + Enter
#
# + 셀 삭제 : Ctrl + M D
#
# ---
#
# + 저장 : Ctrl + S
#
# + 마크다운으로 전환 : **Ctrl + M M**
